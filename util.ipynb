# %%
with open('features2.txt')as f:
    contents = f.readlines()

# %%
contents[288:]
# Out:
# ['advertising\n',
#  'analytics\n',
#  'automotive\n',
#  'biotech\n',
#  'cleantech\n',
#  'consulting\n',
#  'ecommerce\n',
#  'education\n',
#  'enterprise\n',
#  'fashion\n',
#  'finance\n',
#  'games_video\n',
#  'hardware\n',
#  'health\n',
#  'hospitality\n',
#  'manufacturing\n',
#  'medical\n',
#  'messaging\n',
#  'mobile\n',
#  'music\n',
#  'network_hosting\n',
#  'news\n',
#  'other\n',
#  'photo_video\n',
#  'public_relations\n',
#  'real_estate\n',
#  'search\n',
#  'security\n',
#  'semiconductor\n',
#  'social\n',
#  'software\n',
#  'sports\n',
#  'transportation\n',
#  'travel\n',
#  'web\n']

# %% [markdown]
# * contents 1:9 - Numbers
# * contents 9:14- drop down -choose best fits you (state)
# * contents 14-24:- radio button/check box - choose all that apply
# * contents 24:32 - radio button/check box - choose all that apply
# * contents 32:67- drop down -choose best fits you (state)
# * contents 67-288:- drop down -city
# * contents 288:- drop down -category

# %%
contents =[i.replace('is_','') for i in contents ] #remove is_
contents = [i.replace('has_','')for i in contents]#remove has_
contents =[i.replace('city_','') for i in contents ] #remove is_
contents = [i.replace('category_code_','')for i in contents]# remove category_code_
contents = [i.replace('state_code_','')for i in contents]
contents
# Out:
# ['labels\n',
#  'age_first_funding_year\n',
#  'age_last_funding_year\n',
#  'age_first_milestone_year\n',
#  'age_last_milestone_year\n',
#  'relationships\n',
#  'funding_rounds\n',
#  'funding_total_usd\n',
#  'milestones\n',
#  'CA\n',
#  'NY\n',
#  'MA\n',
#  'TX\n',
#  'otherstate\n',
#  'software\n',
#  'web\n',
#  'mobile\n',
#  'enterprise\n',
#  'advertising\n',
#  'gamesvideo\n',
#  'ecommerce\n',
#  'biotech\n',
#  'consulting\n',
#  'othercategory\n',
#  'VC\n',
#  'angel\n',
#  'roundA\n',
#  'roundB\n',
#  'roundC\n',
#  'roundD\n',
#  'avg_participants\n',
#  'top500\n',
#  'AR\n',
#  'AZ\n',
#  'CA\n',
#  'CO\n',
#  'CT\n',
#  'DC\n',
#  'FL\n',
#  'GA\n',
#  'ID\n',
#  'IL\n',
#  'IN\n',
#  'KY\n',
#  'MA\n',
#  'MD\n',
#  'ME\n',
#  'MI\n',
#  'MN\n',
#  'MO\n',
#  'NC\n',
#  'NH\n',
#  'NJ\n',
#  'NM\n',
#  'NV\n',
#  'NY\n',
#  'OH\n',
#  'OR\n',
#  'PA\n',
#  'RI\n',
#  'TN\n',
#  'TX\n',
#  'UT\n',
#  'VA\n',
#  'WA\n',
#  'WI\n',
#  'WV\n',
#  'Acton\n',
# ...
